# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')
credit_card_data=credit_card_data.drop(columns=["V11", "V12", "V13", "V14", "V15", "V16", "V17", "V18", "V19","V20", "V21", "V22", "V23", "V24", "V25",])

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V26       V27       V28  Amount  Class
# 0  0.098698  0.363787  0.090794 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.085102 -0.255425 -0.166974  0.125895 -0.008983  0.014724    2.69      0
# 2  0.247676 -1.514654  0.207643 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.377436 -1.387024 -0.054952 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.270533  0.817739  0.753074  0.502292  0.219422  0.215153   69.99      0

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V26       V27  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170  0.250034  0.943651
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.395255  0.068472
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782 -0.087371  0.004455
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126  0.546668  0.108821
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -0.818267 -0.002415
#
#              V28  Amount  Class
# 284802  0.823731    0.77      0
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V26     284807 non-null  float64
#  12  V27     284807 non-null  float64
#  13  V28     284807 non-null  float64
#  14  Amount  284807 non-null  float64
#  15  Class   284807 non-null  int64
# dtypes: float64(15), int64(1)
# memory usage: 34.8 MB

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 16)
# (492, 16)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V26       V27  \
# Class
# 0      0.002419  0.009637 -0.000987  0.004467  0.009824 -0.000089 -0.000295
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  0.051648  0.170575
#
#             V28      Amount
# Class
# 0     -0.000131   88.291022
# 1      0.075667  122.211321

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9       V10       V26       V27       V28  \
# 279863 -0.882850  0.697211 -2.064945 -5.587794  0.788395  0.292680  0.147968
# 280143 -1.413170  0.248525 -1.127396 -3.232153  0.739467  0.389152  0.186637
# 280149 -2.234739  1.210158 -0.652250 -3.463891  0.471111  0.385107  0.194361
# 281144 -2.208002  1.058733 -1.632333 -5.245984  0.606116  0.884876 -0.253700
# 281674  0.223050 -0.068384  0.577829 -0.888722 -0.289617  0.002988 -0.015309
#
#         Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92538.160569 -0.073157  0.032354  0.041492 -0.068848  0.012343
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V26       V27  \
# Class
# 0      0.036329 -0.068267 -0.049791  0.049834  0.018218  0.026739 -0.008911
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  0.051648  0.170575
#
#             V28      Amount
# Class
# 0     -0.023075   75.556606
# 1      0.075667  122.211321

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 255989  157487.0 -0.257305  0.417160  0.178871 -0.940855  1.400535  0.861881
# 91823    63641.0 -4.744386 -4.864041 -0.700090  2.132830  1.640772  0.283906
# 251626  155429.0 -1.556492 -0.704569 -0.656604 -1.670566  1.312915 -0.468065
# 94917    65087.0 -1.111725  0.142768  2.001787 -1.716540 -1.117883 -0.613383
# 276590  167185.0 -1.413208  0.848789  1.554470  0.646907 -0.527135  1.406833
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 3467    0.0
# 2311    0.0
# 8255    0.0
# 9904    0.0
# 3791    0.0
#        ...
# 9035    1.0
# 9179    1.0
# 9252    1.0
# 9487    1.0
# 9509    1.0
# Name: Class, Length: 530, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print(X_train)
# Out:
#             Time         V1        V2         V3        V4         V5  \
# 100623   67571.0  -0.758469 -0.045410  -0.168438 -1.313275  -1.901763
# 131546   79640.0   1.089866 -0.059374   0.500511  0.910705  -0.090517
# 165785  117661.0   2.035492  0.205841  -1.626249  1.377607   0.427982
# 278485  168244.0   0.102681  0.822708  -0.153591 -0.836835   0.935902
# 118642   75157.0  -1.623865 -0.304065   1.710986 -0.621441   1.067559
# ...          ...        ...       ...        ...       ...        ...
# 54471    46464.0  -0.782140 -1.928194   1.360073 -1.228876  -0.375930
# 95923    65530.0  -0.986245  0.871127  -0.590198 -2.417868   2.161084
# 223618  143456.0  -2.006582  3.676577  -5.463811  7.232058  -1.627859
# 43061    41353.0 -15.020981  8.075240 -16.298091  5.664820 -11.918153
# 268700  163345.0  -0.662024  0.380345   0.800019 -0.708349   0.137595
#
#               V6         V7        V8        V9        V10       V26  \
# ...

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 15) (787, 15) (197, 15)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.934010152284264

# %%
X_input = pd.DataFrame([[94838.202258,	0.008258,	-0.006271,	0.012171,	-0.007860	,0.005453	,0.002419	,0.009637,	-0.000987,	0.004467	,0.009824,	-0.000089	,-0.000295	,-0.000131	,88.291022]],
                       columns=["Time","V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8", "V9","V10", "V26", "V27", "V28", "Amount"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adc369b1948c> in <cell line: 0>()
# ----> 1 X_input = pd.DataFrame([[94838.202258,	0.008258,	-0.006271,	0.012171,	-0.007860	,0.005453	,0.002419	,0.009637,	-0.000987,	0.004467	,0.009824,	-0.000089	,-0.000295	,-0.000131	,88.291022]],
#       2                        columns=["Time","V1", "V2", "V3", "V4", "V5", "V6", "V7", "V8", "V9","V10", "V26", "V27", "V28", "Amount"])
#
# NameError: name 'pd' is not defined

# %%
X_test = model.predict(X_input)
print(X_test);
# Out:
# [0]

# %%
import pickle

# %%
with open('model_pickle','wb') as file:
    pickle.dump(model,file)
